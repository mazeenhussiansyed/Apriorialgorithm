# %%
import pandas as pd
import itertools
import time

# Function to load transactions from a CSV file
def load_transactions(store_name):
    try:
        df = pd.read_csv(store_name, header=None)  # Read the CSV file
        transactions = df.values.tolist()  # Convert to a list
        return [list(map(str, transaction)) for transaction in transactions]  # Make sure items are strings
    
    except FileNotFoundError:
        print(f"File {store_name} not found.")  # Handle file not found error
        return None


# Function to find itemsets using the Brute Force method
def generate_itemsets_brute_force(transactions, min_support):
    items = set()
    for transaction in transactions:
        items.update(transaction)  # Collect all unique items
    frequent_itemsets = []
    k = 1
    while True:
        itemsets = list(itertools.combinations(items, k))  # Get all combinations of items of size k
        temp = []
        for itemset in itemsets:
            count = sum(1 for transaction in transactions if set(itemset).issubset(set(transaction)))  # Count how many transactions contain this itemset
            if count / len(transactions) >= min_support:  # Check if it meets the minimum support
                temp.append(itemset)
        if not temp:  # If no more itemsets found, stop
            break
        frequent_itemsets.extend(temp)  # Add found itemsets to the list
        k += 1  # Increase size for the next round
    return frequent_itemsets

# Function to find itemsets using the Apriori algorithm
def apriori_algorithm(transactions, min_support):
    items = set()
    for transaction in transactions:
        items.update(transaction)  # Collect all unique items
    frequent_itemsets = []
    k = 1
    while True:
        itemsets = list(itertools.combinations(items, k))  # Get all combinations of size k
        temp = []
        for itemset in itemsets:
            count = sum(1 for transaction in transactions if set(itemset).issubset(set(transaction)))  # Count the itemsets
            if count / len(transactions) >= min_support:  # Check support
                temp.append(itemset)
        if not temp:  # Stop if no itemsets are found
            break
        frequent_itemsets.extend(temp)  # Add found itemsets
        k += 1  # Increase size for next round
        # Prune the itemsets to speed up
        itemsets = [itemset for itemset in itemsets if all(subset in frequent_itemsets for subset in itertools.combinations(itemset, k - 1))]
    return frequent_itemsets

# FP-Growth algorithm implementation
class TreeNode:
    def __init__(self, item, count):
        self.item = item  # The item in this node
        self.count = count  # How many times it appears
        self.children = []  # Children nodes

# Create FP Tree
def create_fp_tree(transactions, min_support):
    root = TreeNode(None, 0)  # Root node
    item_count = {}
    
    # Count how many times each item appears
    for transaction in transactions:
        for item in transaction:
            item_count[item] = item_count.get(item, 0) + 1
    
    print(f"Item counts: {item_count}")  # Show item counts for debugging
    
    # Remove items that don't meet the minimum support
    item_count = {item: count for item, count in item_count.items() if count / len(transactions) >= min_support}
    
    print(f"Filtered item counts (min_support={min_support}): {item_count}")  # Show filtered counts for debugging

    for transaction in transactions:
        # Keep only items that meet support and sort by frequency
        frequent_items = [item for item in transaction if item in item_count]
        frequent_items.sort(key=lambda x: item_count[x], reverse=True)  # Sort items by count
        
        current_node = root
        for item in frequent_items:
            found = False
            for child in current_node.children:
                if child.item == item:
                    child.count += 1  # Increment count if item already exists
                    current_node = child  # Move to the child node
                    found = True
                    break
            if not found:
                new_node = TreeNode(item, 1)  # Create new node
                current_node.children.append(new_node)  # Add it to children
                current_node = new_node  # Move to the new node
    
    return root

# FP-Growth function
def fp_growth(transactions, min_support):
    fp_tree = create_fp_tree(transactions, min_support)  # Create the FP tree
    frequent_itemsets = []

    def fp_growth_helper(node, prefix):
        if node.item is not None and node.count / len(transactions) >= min_support:
            frequent_itemsets.append(prefix + (node.item,))  # Add frequent itemset
        
        for child in node.children:
            fp_growth_helper(child, prefix + (child.item,))  # Recur for children
    
    fp_growth_helper(fp_tree, ())  # Start recursive function
    print(f"Frequent itemsets found by FP-Growth: {frequent_itemsets}") 
    return frequent_itemsets

# Function to generate association rules
def generate_association_rules(frequent_itemsets, transactions, min_confidence):
    association_rules = []
    for itemset in frequent_itemsets:
        for i in range(1, len(itemset)):
            subsets = list(itertools.combinations(itemset, i))  # Get all subsets of the itemset
            for subset in subsets:
                count = sum(1 for transaction in transactions if set(subset).issubset(set(transaction)))  # Count occurrences
                confidence = count / len(transactions)  # Calculate confidence
                if confidence >= min_confidence:  # Check if it meets the confidence threshold
                    association_rules.append((subset, tuple(set(itemset) - set(subset)), confidence))  
    return association_rules

# Main function
def main():
    stores = [
        "datasets/Grocery_Store_transactions.csv",
        "datasets/Electronics_Store_transactions.csv",
        "datasets/Clothing_Store_transactions.csv",
        "datasets/Bookstore_transactions.csv",
        "datasets/Home_Improvement_Store_transactions.csv"
    ]
    
    validate = False
    while not validate:
        print("Select a store:")  # Print statement to select the store
        for i, store in enumerate(stores):
            print(f"{i + 1}. {store}")

        store_choice = int(input("Enter the store number: "))
         # Validate store choice
        if store_choice < 1 or store_choice > len(stores):
            print("Please enter a valid store number from the given options.")
        else:
            validate = True
            
        
    store_name = stores[store_choice - 1] 
    transactions = load_transactions(store_name)  # Load transactions
    
    
    if transactions is None:
        return  # Exit if transactions couldn't be loaded
    
    min_support = int(input("Enter the minimum support threshold (1 to 100): ")) / 100.0  # Get support threshold
    min_confidence = int(input("Enter the minimum confidence threshold (1 to 100): ")) / 100.0  # Get confidence threshold
    
    # Timing Brute Force Method
    start_time = time.time()
    print("\nBrute Force Method:")
    brute_force_itemsets = generate_itemsets_brute_force(transactions, min_support)  # Run brute force
    print(f"Frequent itemsets: {brute_force_itemsets}")
    print(f"Time taken: {time.time() - start_time:.4f} seconds")

    # Timing Apriori Algorithm
    start_time = time.time()
    print("\nApriori Algorithm:")
    apriori_itemsets = apriori_algorithm(transactions, min_support)  # Run Apriori
    print(f"Frequent itemsets: {apriori_itemsets}")
    print(f"Time taken: {time.time() - start_time:.4f} seconds")

    # Timing FP-Growth Algorithm
    start_time = time.time()
    print("\nFP-Growth Algorithm:")
    fp_growth_itemsets = fp_growth(transactions, min_support)  # Run FP-Growth
    print(f"Frequent itemsets: {fp_growth_itemsets}")
    print(f"Time taken: {time.time() - start_time:.4f} seconds")

    # Generating Association Rules
    print("\nGenerating Association Rules:")
    all_itemsets = set(brute_force_itemsets + apriori_itemsets + fp_growth_itemsets)  # Combine all itemsets
    association_rules = generate_association_rules(all_itemsets, transactions, min_confidence)  # Generate rules
    
    print("Association Rules:")
    for rule in association_rules:
        print(f"{rule[0]} -> {rule[1]} (confidence: {rule[2]:.2f})")  # This shows the final Association rules

if __name__ == "__main__":
    main()
# Out:
# Select a store:
# 1. datasets/Grocery_Store_transactions.csv
# 2. datasets/Electronics_Store_transactions.csv
# 3. datasets/Clothing_Store_transactions.csv
# 4. datasets/Bookstore_transactions.csv
# 5. datasets/Home_Improvement_Store_transactions.csv
# Enter the store number: 2
# Enter the minimum support threshold (1 to 100): 20
# Enter the minimum confidence threshold (1 to 100): 30
#
# Brute Force Method:
# Frequent itemsets: [('Smartwatch',), ('Mouse',), ('Camera',), ('Laptop',), ('Headphones',), ('Monitor',), ('Smartphone',), ('nan',), ('Speaker',), ('Keyboard',), ('Charger',), ('Smartwatch', 'Mouse'), ('Smartwatch', 'Camera'), ('Smartwatch', 'Laptop'), ('Smartwatch', 'Headphones'), ('Smartwatch', 'Monitor'), ('Smartwatch', 'Smartphone'), ('Smartwatch', 'nan'), ('Smartwatch', 'Speaker'), ('Smartwatch', 'Keyboard'), ('Smartwatch', 'Charger'), ('Mouse', 'Camera'), ('Mouse', 'Laptop'), ('Mouse', 'Headphones'), ('Mouse', 'Monitor'), ('Mouse', 'Smartphone'), ('Mouse', 'nan'), ('Mouse', 'Speaker'), ('Mouse', 'Keyboard'), ('Mouse', 'Charger'), ('Camera', 'Laptop'), ('Camera', 'Headphones'), ('Camera', 'Monitor'), ('Camera', 'Smartphone'), ('Camera', 'nan'), ('Camera', 'Speaker'), ('Camera', 'Keyboard'), ('Camera', 'Charger'), ('Laptop', 'Headphones'), ('Laptop', 'Monitor'), ('Laptop', 'Smartphone'), ('Laptop', 'nan'), ('Laptop', 'Speaker'), ('Laptop', 'Keyboard'), ('Laptop', 'Charger'), ('Headphones', 'Monitor'), ('Headphones', 'Smartphone'), ('Headphones', 'nan'), ('Headphones', 'Speaker'), ('Headphones', 'Keyboard'), ('Headphones', 'Charger'), ('Monitor', 'Smartphone'), ('Monitor', 'nan'), ('Monitor', 'Speaker'), ('Monitor', 'Keyboard'), ('Monitor', 'Charger'), ('Smartphone', 'nan'), ('Smartphone', 'Speaker'), ('Smartphone', 'Keyboard'), ('Smartphone', 'Charger'), ('nan', 'Speaker'), ('nan', 'Keyboard'), ('nan', 'Charger'), ('Speaker', 'Keyboard'), ('Speaker', 'Charger'), ('Keyboard', 'Charger'), ('Smartwatch', 'Mouse', 'Camera'), ('Smartwatch', 'Mouse', 'Laptop'), ('Smartwatch', 'Mouse', 'Headphones'), ('Smartwatch', 'Mouse', 'Monitor'), ('Smartwatch', 'Mouse', 'Smartphone'), ('Smartwatch', 'Mouse', 'nan'), ('Smartwatch', 'Mouse', 'Speaker'), ('Smartwatch', 'Mouse', 'Keyboard'), ('Smartwatch', 'Mouse', 'Charger'), ('Smartwatch', 'Camera', 'Laptop'), ('Smartwatch', 'Camera', 'Headphones'), ('Smartwatch', 'Camera', 'Monitor'), ('Smartwatch', 'Camera', 'Smartphone'), ('Smartwatch', 'Camera', 'nan'), ('Smartwatch', 'Camera', 'Speaker'), ('Smartwatch', 'Camera', 'Keyboard'), ('Smartwatch', 'Camera', 'Charger'), ('Smartwatch', 'Laptop', 'Headphones'), ('Smartwatch', 'Laptop', 'Monitor'), ('Smartwatch', 'Laptop', 'Smartphone'), ('Smartwatch', 'Laptop', 'nan'), ('Smartwatch', 'Laptop', 'Speaker'), ('Smartwatch', 'Laptop', 'Keyboard'), ('Smartwatch', 'Laptop', 'Charger'), ('Smartwatch', 'Headphones', 'Monitor'), ('Smartwatch', 'Headphones', 'Smartphone'), ('Smartwatch', 'Headphones', 'nan'), ('Smartwatch', 'Headphones', 'Speaker'), ('Smartwatch', 'Headphones', 'Keyboard'), ('Smartwatch', 'Headphones', 'Charger'), ('Smartwatch', 'Monitor', 'Smartphone'), ('Smartwatch', 'Monitor', 'nan'), ('Smartwatch', 'Monitor', 'Speaker'), ('Smartwatch', 'Monitor', 'Keyboard'), ('Smartwatch', 'Monitor', 'Charger'), ('Smartwatch', 'Smartphone', 'nan'), ('Smartwatch', 'Smartphone', 'Speaker'), ('Smartwatch', 'Smartphone', 'Keyboard'), ('Smartwatch', 'Smartphone', 'Charger'), ('Smartwatch', 'nan', 'Speaker'), ('Smartwatch', 'nan', 'Keyboard'), ('Smartwatch', 'nan', 'Charger'), ('Smartwatch', 'Speaker', 'Keyboard'), ('Smartwatch', 'Speaker', 'Charger'), ('Smartwatch', 'Keyboard', 'Charger'), ('Mouse', 'Camera', 'Laptop'), ('Mouse', 'Camera', 'Headphones'), ('Mouse', 'Camera', 'Monitor'), ('Mouse', 'Camera', 'Smartphone'), ('Mouse', 'Camera', 'nan'), ('Mouse', 'Camera', 'Speaker'), ('Mouse', 'Camera', 'Keyboard'), ('Mouse', 'Camera', 'Charger'), ('Mouse', 'Laptop', 'Headphones'), ('Mouse', 'Laptop', 'Monitor'), ('Mouse', 'Laptop', 'Smartphone'), ('Mouse', 'Laptop', 'nan'), ('Mouse', 'Laptop', 'Speaker'), ('Mouse', 'Laptop', 'Keyboard'), ('Mouse', 'Laptop', 'Charger'), ('Mouse', 'Headphones', 'Monitor'), ('Mouse', 'Headphones', 'Smartphone'), ('Mouse', 'Headphones', 'nan'), ('Mouse', 'Headphones', 'Speaker'), ('Mouse', 'Headphones', 'Keyboard'), ('Mouse', 'Headphones', 'Charger'), ('Mouse', 'Monitor', 'Smartphone'), ('Mouse', 'Monitor', 'nan'), ('Mouse', 'Monito ...
# Time taken: 0.1598 seconds
#
# Apriori Algorithm:
# Frequent itemsets: [('Smartwatch',), ('Mouse',), ('Camera',), ('Laptop',), ('Headphones',), ('Monitor',), ('Smartphone',), ('nan',), ('Speaker',), ('Keyboard',), ('Charger',), ('Smartwatch', 'Mouse'), ('Smartwatch', 'Camera'), ('Smartwatch', 'Laptop'), ('Smartwatch', 'Headphones'), ('Smartwatch', 'Monitor'), ('Smartwatch', 'Smartphone'), ('Smartwatch', 'nan'), ('Smartwatch', 'Speaker'), ('Smartwatch', 'Keyboard'), ('Smartwatch', 'Charger'), ('Mouse', 'Camera'), ('Mouse', 'Laptop'), ('Mouse', 'Headphones'), ('Mouse', 'Monitor'), ('Mouse', 'Smartphone'), ('Mouse', 'nan'), ('Mouse', 'Speaker'), ('Mouse', 'Keyboard'), ('Mouse', 'Charger'), ('Camera', 'Laptop'), ('Camera', 'Headphones'), ('Camera', 'Monitor'), ('Camera', 'Smartphone'), ('Camera', 'nan'), ('Camera', 'Speaker'), ('Camera', 'Keyboard'), ('Camera', 'Charger'), ('Laptop', 'Headphones'), ('Laptop', 'Monitor'), ('Laptop', 'Smartphone'), ('Laptop', 'nan'), ('Laptop', 'Speaker'), ('Laptop', 'Keyboard'), ('Laptop', 'Charger'), ('Headphones', 'Monitor'), ('Headphones', 'Smartphone'), ('Headphones', 'nan'), ('Headphones', 'Speaker'), ('Headphones', 'Keyboard'), ('Headphones', 'Charger'), ('Monitor', 'Smartphone'), ('Monitor', 'nan'), ('Monitor', 'Speaker'), ('Monitor', 'Keyboard'), ('Monitor', 'Charger'), ('Smartphone', 'nan'), ('Smartphone', 'Speaker'), ('Smartphone', 'Keyboard'), ('Smartphone', 'Charger'), ('nan', 'Speaker'), ('nan', 'Keyboard'), ('nan', 'Charger'), ('Speaker', 'Keyboard'), ('Speaker', 'Charger'), ('Keyboard', 'Charger'), ('Smartwatch', 'Mouse', 'Camera'), ('Smartwatch', 'Mouse', 'Laptop'), ('Smartwatch', 'Mouse', 'Headphones'), ('Smartwatch', 'Mouse', 'Monitor'), ('Smartwatch', 'Mouse', 'Smartphone'), ('Smartwatch', 'Mouse', 'nan'), ('Smartwatch', 'Mouse', 'Speaker'), ('Smartwatch', 'Mouse', 'Keyboard'), ('Smartwatch', 'Mouse', 'Charger'), ('Smartwatch', 'Camera', 'Laptop'), ('Smartwatch', 'Camera', 'Headphones'), ('Smartwatch', 'Camera', 'Monitor'), ('Smartwatch', 'Camera', 'Smartphone'), ('Smartwatch', 'Camera', 'nan'), ('Smartwatch', 'Camera', 'Speaker'), ('Smartwatch', 'Camera', 'Keyboard'), ('Smartwatch', 'Camera', 'Charger'), ('Smartwatch', 'Laptop', 'Headphones'), ('Smartwatch', 'Laptop', 'Monitor'), ('Smartwatch', 'Laptop', 'Smartphone'), ('Smartwatch', 'Laptop', 'nan'), ('Smartwatch', 'Laptop', 'Speaker'), ('Smartwatch', 'Laptop', 'Keyboard'), ('Smartwatch', 'Laptop', 'Charger'), ('Smartwatch', 'Headphones', 'Monitor'), ('Smartwatch', 'Headphones', 'Smartphone'), ('Smartwatch', 'Headphones', 'nan'), ('Smartwatch', 'Headphones', 'Speaker'), ('Smartwatch', 'Headphones', 'Keyboard'), ('Smartwatch', 'Headphones', 'Charger'), ('Smartwatch', 'Monitor', 'Smartphone'), ('Smartwatch', 'Monitor', 'nan'), ('Smartwatch', 'Monitor', 'Speaker'), ('Smartwatch', 'Monitor', 'Keyboard'), ('Smartwatch', 'Monitor', 'Charger'), ('Smartwatch', 'Smartphone', 'nan'), ('Smartwatch', 'Smartphone', 'Speaker'), ('Smartwatch', 'Smartphone', 'Keyboard'), ('Smartwatch', 'Smartphone', 'Charger'), ('Smartwatch', 'nan', 'Speaker'), ('Smartwatch', 'nan', 'Keyboard'), ('Smartwatch', 'nan', 'Charger'), ('Smartwatch', 'Speaker', 'Keyboard'), ('Smartwatch', 'Speaker', 'Charger'), ('Smartwatch', 'Keyboard', 'Charger'), ('Mouse', 'Camera', 'Laptop'), ('Mouse', 'Camera', 'Headphones'), ('Mouse', 'Camera', 'Monitor'), ('Mouse', 'Camera', 'Smartphone'), ('Mouse', 'Camera', 'nan'), ('Mouse', 'Camera', 'Speaker'), ('Mouse', 'Camera', 'Keyboard'), ('Mouse', 'Camera', 'Charger'), ('Mouse', 'Laptop', 'Headphones'), ('Mouse', 'Laptop', 'Monitor'), ('Mouse', 'Laptop', 'Smartphone'), ('Mouse', 'Laptop', 'nan'), ('Mouse', 'Laptop', 'Speaker'), ('Mouse', 'Laptop', 'Keyboard'), ('Mouse', 'Laptop', 'Charger'), ('Mouse', 'Headphones', 'Monitor'), ('Mouse', 'Headphones', 'Smartphone'), ('Mouse', 'Headphones', 'nan'), ('Mouse', 'Headphones', 'Speaker'), ('Mouse', 'Headphones', 'Keyboard'), ('Mouse', 'Headphones', 'Charger'), ('Mouse', 'Monitor', 'Smartphone'), ('Mouse', 'Monitor', 'nan'), ('Mouse', 'Monito ...
# Time taken: 0.1410 seconds
#
# FP-Growth Algorithm:
# Item counts: {'Charger': 22, 'Laptop': 27, 'Camera': 20, 'Headphones': 28, 'Keyboard': 29, 'Monitor': 27, 'Mouse': 23, 'Smartphone': 29, 'nan': 152, 'Smartwatch': 23, 'Speaker': 20}
# Filtered item counts (min_support=0.2): {'Charger': 22, 'Laptop': 27, 'Camera': 20, 'Headphones': 28, 'Keyboard': 29, 'Monitor': 27, 'Mouse': 23, 'Smartphone': 29, 'nan': 152, 'Smartwatch': 23, 'Speaker': 20}
# Frequent itemsets found by FP-Growth: [('nan', 'nan'), ('nan', 'nan', 'nan'), ('nan', 'nan', 'Keyboard', 'Keyboard'), ('nan', 'nan', 'Keyboard', 'Smartphone', 'Smartphone'), ('nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan')]
# Frequent itemsets: [('nan', 'nan'), ('nan', 'nan', 'nan'), ('nan', 'nan', 'Keyboard', 'Keyboard'), ('nan', 'nan', 'Keyboard', 'Smartphone', 'Smartphone'), ('nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'), ('nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan')]
# Time taken: 0.0014 seconds
#
# Generating Association Rules:
# Association Rules:
# ('Smartwatch',) -> ('Keyboard', 'Smartphone', 'Charger') (confidence: 0.57)
# ('Smartphone',) -> ('Keyboard', 'Charger', 'Smartwatch') (confidence: 0.72)
# ('Keyboard',) -> ('Smartphone', 'Charger', 'Smartwatch') (confidence: 0.72)
# ('Charger',) -> ('Keyboard', 'Smartphone', 'Smartwatch') (confidence: 0.55)
# ('Smartwatch', 'Smartphone') -> ('Keyboard', 'Charger') (confidence: 0.47)
# ('Smartwatch', 'Keyboard') -> ('Smartphone', 'Charger') (confidence: 0.50)
# ('Smartwatch', 'Charger') -> ('Keyboard', 'Smartphone') (confidence: 0.38)
# ('Smartphone', 'Keyboard') -> ('Charger', 'Smartwatch') (confidence: 0.62)
# ('Smartphone', 'Charger') -> ('Keyboard', 'Smartwatch') (confidence: 0.55)
# ('Keyboard', 'Charger') -> ('Smartphone', 'Smartwatch') (confidence: 0.53)
# ('Smartwatch', 'Smartphone', 'Keyboard') -> ('Charger',) (confidence: 0.45)
# ('Smartwatch', 'Smartphone', 'Charger') -> ('Keyboard',) (confidence: 0.38)
# ('Smartwatch', 'Keyboard', 'Charger') -> ('Smartphone',) (confidence: 0.35)
# ('Smartphone', 'Keyboard', 'Charger') -> ('Smartwatch',) (confidence: 0.53)
# ('Smartwatch',) -> ('Camera', 'Charger') (confidence: 0.57)
# ('Camera',) -> ('Charger', 'Smartwatch') (confidence: 0.50)
# ('Charger',) -> ('Camera', 'Smartwatch') (confidence: 0.55)
# ('Smartwatch', 'Camera') -> ('Charger',) (confidence: 0.30)
# ('Smartwatch', 'Charger') -> ('Camera',) (confidence: 0.38)
# ('Camera', 'Charger') -> ('Smartwatch',) (confidence: 0.42)
# ('Smartwatch',) -> ('Camera', 'Monitor', 'Headphones') (confidence: 0.57)
# ('Camera',) -> ('Monitor', 'Headphones', 'Smartwatch') (confidence: 0.50)
# ('Headphones',) -> ('Camera', 'Monitor', 'Smartwatch') (confidence: 0.70)
# ('Monitor',) -> ('Camera', 'Headphones', 'Smartwatch') (confidence: 0.68)
# ('Smartwatch', 'Camera') -> ('Monitor', 'Headphones') (confidence: 0.30)
# ('Smartwatch', 'Headphones') -> ('Camera', 'Monitor') (confidence: 0.47)
# ('Smartwatch', 'Monitor') -> ('Camera', 'Headphones') (confidence: 0.42)
# ('Camera', 'Headphones') -> ('Monitor', 'Smartwatch') (confidence: 0.40)
# ('Camera', 'Monitor') -> ('Headphones', 'Smartwatch') (confidence: 0.38)
# ('Headphones', 'Monitor') -> ('Camera', 'Smartwatch') (confidence: 0.65)
# ('Smartwatch', 'Headphones', 'Monitor') -> ('Camera',) (confidence: 0.42)
# ('Camera', 'Headphones', 'Monitor') -> ('Smartwatch',) (confidence: 0.35)
# ('Smartwatch',) -> ('Monitor', 'Laptop', 'Headphones', 'Speaker', 'Smartphone') (confidence: 0.57)
# ('Laptop',) -> ('Smartwatch', 'Monitor', 'Headphones', 'Smartphone', 'Speaker') (confidence: 0.68)
# ('Headphones',) -> ('Smartwatch', 'Monitor', 'Laptop', 'Smartphone', 'Speaker') (confidence: 0.70)
# ('Monitor',) -> ('Smartwatch', 'Smartphone', 'Laptop', 'Headphones', 'Speaker') (confidence: 0.68)
# ('Smartphone',) -> ('Smartwatch', 'Monitor', 'Laptop', 'Headphones', 'Speaker') (confidence: 0.72)
# ('Speaker',) -> ('Smartwatch', 'Monitor', 'Laptop', 'Headphones', 'Smartphone') (confidence: 0.50)
# ('Smartwatch', 'Laptop') -> ('Monitor', 'Headphones', 'Speaker', 'Smartphone') (confidence: 0.40)
# ('Smartwatch', 'Headphones') -> ('Monitor', 'Laptop', 'Speaker', 'Smartphone') (confidence: 0.47)
# ('Smartwatch', 'Monitor') -> ('Smartphone', 'Laptop', 'Speaker', 'Headphones') (confidence: 0.42)
# ('Smartwatch', 'Smartphone') -> ('Monitor', 'Laptop', 'Speaker', 'Headphones') (confidence: 0.47)
# ('Smartwatch', 'Speaker') -> ('Monitor', 'Laptop', 'Headphones', 'Smartphone') (confidence: 0.40)
# ('Laptop', 'Headphones') -> ('Monitor', 'Smartwatch', 'Speaker', 'Smartphone') (confidence: 0.57)
# ('Laptop', 'Monitor') -> ('Smartphone', 'Headphones', 'Smartwatch', 'Speaker') (confidence: 0.55)
# ('Laptop', 'Smartphone') -> ('Monitor', 'Headphones', 'Smartwatch', 'Speaker') (confidence: 0.60)
# ('Laptop', 'Speaker') -> ('Monitor', 'Headphones', 'Smartwatch', 'Smartphone') (confidence: 0.45)
# ('Headphones', 'Monitor') -> ('Smartphone', 'Laptop', 'Smartwatch', 'Speaker') (confidence: 0.65)
# ('Headphones', 'Smartphone') -> ('Monitor', 'Laptop', 'Smartwatch', 'Speaker') (confidence: 0.60)
# ('Headphones', 'Speaker') -> ('Monitor', 'Laptop', 'Smartwatch', 'Smartphone') (confidence: 0.38)
# ('Monitor', 'Smartphone') -> ('Speaker', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.57)
# ('Monitor', 'Speaker') -> ('Smartphone', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.35)
# ('Smartphone', 'Speaker') -> ('Monitor', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.40)
# ('Smartwatch', 'Laptop', 'Headphones') -> ('Monitor', 'Speaker', 'Smartphone') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Monitor') -> ('Smartphone', 'Headphones', 'Speaker') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Smartphone') -> ('Monitor', 'Headphones', 'Speaker') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Speaker') -> ('Monitor', 'Headphones', 'Smartphone') (confidence: 0.40)
# ('Smartwatch', 'Headphones', 'Monitor') -> ('Smartphone', 'Laptop', 'Speaker') (confidence: 0.42)
# ('Smartwatch', 'Headphones', 'Smartphone') -> ('Monitor', 'Laptop', 'Speaker') (confidence: 0.38)
# ('Smartwatch', 'Headphones', 'Speaker') -> ('Monitor', 'Laptop', 'Smartphone') (confidence: 0.35)
# ('Smartwatch', 'Monitor', 'Smartphone') -> ('Laptop', 'Speaker', 'Headphones') (confidence: 0.33)
# ('Smartwatch', 'Monitor', 'Speaker') -> ('Smartphone', 'Laptop', 'Headphones') (confidence: 0.30)
# ('Smartwatch', 'Smartphone', 'Speaker') -> ('Monitor', 'Laptop', 'Headphones') (confidence: 0.35)
# ('Laptop', 'Headphones', 'Monitor') -> ('Smartphone', 'Smartwatch', 'Speaker') (confidence: 0.53)
# ('Laptop', 'Headphones', 'Smartphone') -> ('Monitor', 'Smartwatch', 'Speaker') (confidence: 0.53)
# ('Laptop', 'Headphones', 'Speaker') -> ('Monitor', 'Smartwatch', 'Smartphone') (confidence: 0.38)
# ('Laptop', 'Monitor', 'Smartphone') -> ('Headphones', 'Smartwatch', 'Speaker') (confidence: 0.50)
# ('Laptop', 'Monitor', 'Speaker') -> ('Smartphone', 'Headphones', 'Smartwatch') (confidence: 0.35)
# ('Laptop', 'Smartphone', 'Speaker') -> ('Monitor', 'Headphones', 'Smartwatch') (confidence: 0.40)
# ('Headphones', 'Monitor', 'Smartphone') -> ('Laptop', 'Smartwatch', 'Speaker') (confidence: 0.55)
# ('Headphones', 'Monitor', 'Speaker') -> ('Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.33)
# ('Headphones', 'Smartphone', 'Speaker') -> ('Monitor', 'Laptop', 'Smartwatch') (confidence: 0.33)
# ('Monitor', 'Smartphone', 'Speaker') -> ('Laptop', 'Smartwatch', 'Headphones') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones', 'Monitor') -> ('Smartphone', 'Speaker') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones', 'Smartphone') -> ('Monitor', 'Speaker') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones', 'Speaker') -> ('Monitor', 'Smartphone') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Monitor', 'Speaker') -> ('Smartphone', 'Headphones') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Speaker') -> ('Monitor', 'Headphones') (confidence: 0.35)
# ('Smartwatch', 'Headphones', 'Monitor', 'Smartphone') -> ('Laptop', 'Speaker') (confidence: 0.33)
# ('Smartwatch', 'Headphones', 'Monitor', 'Speaker') -> ('Smartphone', 'Laptop') (confidence: 0.30)
# ('Smartwatch', 'Headphones', 'Smartphone', 'Speaker') -> ('Monitor', 'Laptop') (confidence: 0.30)
# ('Laptop', 'Headphones', 'Monitor', 'Smartphone') -> ('Smartwatch', 'Speaker') (confidence: 0.47)
# ('Laptop', 'Headphones', 'Monitor', 'Speaker') -> ('Smartphone', 'Smartwatch') (confidence: 0.33)
# ('Laptop', 'Headphones', 'Smartphone', 'Speaker') -> ('Monitor', 'Smartwatch') (confidence: 0.33)
# ('Laptop', 'Monitor', 'Smartphone', 'Speaker') -> ('Headphones', 'Smartwatch') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones', 'Monitor', 'Speaker') -> ('Smartphone',) (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones', 'Smartphone', 'Speaker') -> ('Monitor',) (confidence: 0.30)
# ('Camera',) -> ('nan',) (confidence: 0.50)
# ('nan',) -> ('Camera',) (confidence: 0.90)
# ('Smartwatch',) -> ('Camera', 'Laptop', 'Headphones', 'Smartphone', 'Charger') (confidence: 0.57)
# ('Camera',) -> ('Smartwatch', 'Smartphone', 'Laptop', 'Headphones', 'Charger') (confidence: 0.50)
# ('Laptop',) -> ('Smartwatch', 'Camera', 'Headphones', 'Smartphone', 'Charger') (confidence: 0.68)
# ('Headphones',) -> ('Smartwatch', 'Camera', 'Laptop', 'Smartphone', 'Charger') (confidence: 0.70)
# ('Smartphone',) -> ('Smartwatch', 'Camera', 'Laptop', 'Headphones', 'Charger') (confidence: 0.72)
# ('Charger',) -> ('Smartwatch', 'Camera', 'Laptop', 'Headphones', 'Smartphone') (confidence: 0.55)
# ('Smartwatch', 'Camera') -> ('Charger', 'Smartphone', 'Laptop', 'Headphones') (confidence: 0.30)
# ('Smartwatch', 'Laptop') -> ('Charger', 'Camera', 'Headphones', 'Smartphone') (confidence: 0.40)
# ('Smartwatch', 'Headphones') -> ('Charger', 'Camera', 'Laptop', 'Smartphone') (confidence: 0.47)
# ('Smartwatch', 'Smartphone') -> ('Charger', 'Camera', 'Laptop', 'Headphones') (confidence: 0.47)
# ('Smartwatch', 'Charger') -> ('Camera', 'Laptop', 'Headphones', 'Smartphone') (confidence: 0.38)
# ('Camera', 'Laptop') -> ('Charger', 'Smartphone', 'Headphones', 'Smartwatch') (confidence: 0.47)
# ('Camera', 'Headphones') -> ('Charger', 'Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.40)
# ('Camera', 'Smartphone') -> ('Charger', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.42)
# ('Camera', 'Charger') -> ('Smartphone', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.42)
# ('Laptop', 'Headphones') -> ('Camera', 'Charger', 'Smartwatch', 'Smartphone') (confidence: 0.57)
# ('Laptop', 'Smartphone') -> ('Charger', 'Camera', 'Headphones', 'Smartwatch') (confidence: 0.60)
# ('Laptop', 'Charger') -> ('Camera', 'Headphones', 'Smartwatch', 'Smartphone') (confidence: 0.53)
# ('Headphones', 'Smartphone') -> ('Charger', 'Camera', 'Laptop', 'Smartwatch') (confidence: 0.60)
# ('Headphones', 'Charger') -> ('Camera', 'Laptop', 'Smartwatch', 'Smartphone') (confidence: 0.45)
# ('Smartphone', 'Charger') -> ('Camera', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.55)
# ('Smartwatch', 'Camera', 'Laptop') -> ('Charger', 'Smartphone', 'Headphones') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones') -> ('Camera', 'Charger', 'Smartphone') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Smartphone') -> ('Charger', 'Camera', 'Headphones') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Charger') -> ('Camera', 'Headphones', 'Smartphone') (confidence: 0.35)
# ('Smartwatch', 'Headphones', 'Smartphone') -> ('Charger', 'Camera', 'Laptop') (confidence: 0.38)
# ('Smartwatch', 'Headphones', 'Charger') -> ('Camera', 'Laptop', 'Smartphone') (confidence: 0.30)
# ('Smartwatch', 'Smartphone', 'Charger') -> ('Camera', 'Laptop', 'Headphones') (confidence: 0.38)
# ('Camera', 'Laptop', 'Headphones') -> ('Smartphone', 'Charger', 'Smartwatch') (confidence: 0.40)
# ('Camera', 'Laptop', 'Smartphone') -> ('Charger', 'Headphones', 'Smartwatch') (confidence: 0.42)
# ('Camera', 'Laptop', 'Charger') -> ('Smartphone', 'Headphones', 'Smartwatch') (confidence: 0.42)
# ('Camera', 'Headphones', 'Smartphone') -> ('Charger', 'Laptop', 'Smartwatch') (confidence: 0.35)
# ('Camera', 'Headphones', 'Charger') -> ('Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.35)
# ('Camera', 'Smartphone', 'Charger') -> ('Laptop', 'Smartwatch', 'Headphones') (confidence: 0.42)
# ('Laptop', 'Headphones', 'Smartphone') -> ('Camera', 'Charger', 'Smartwatch') (confidence: 0.53)
# ('Laptop', 'Headphones', 'Charger') -> ('Camera', 'Smartwatch', 'Smartphone') (confidence: 0.45)
# ('Laptop', 'Smartphone', 'Charger') -> ('Camera', 'Headphones', 'Smartwatch') (confidence: 0.53)
# ('Headphones', 'Smartphone', 'Charger') -> ('Camera', 'Laptop', 'Smartwatch') (confidence: 0.45)
# ('Smartwatch', 'Laptop', 'Headphones', 'Smartphone') -> ('Camera', 'Charger') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones', 'Charger') -> ('Camera', 'Smartphone') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Charger') -> ('Camera', 'Headphones') (confidence: 0.35)
# ('Smartwatch', 'Headphones', 'Smartphone', 'Charger') -> ('Camera', 'Laptop') (confidence: 0.30)
# ('Camera', 'Laptop', 'Headphones', 'Smartphone') -> ('Charger', 'Smartwatch') (confidence: 0.35)
# ('Camera', 'Laptop', 'Headphones', 'Charger') -> ('Smartphone', 'Smartwatch') (confidence: 0.35)
# ('Camera', 'Laptop', 'Smartphone', 'Charger') -> ('Headphones', 'Smartwatch') (confidence: 0.42)
# ('Camera', 'Headphones', 'Smartphone', 'Charger') -> ('Laptop', 'Smartwatch') (confidence: 0.35)
# ('Laptop', 'Headphones', 'Smartphone', 'Charger') -> ('Camera', 'Smartwatch') (confidence: 0.45)
# ('Smartwatch', 'Laptop', 'Headphones', 'Smartphone', 'Charger') -> ('Camera',) (confidence: 0.30)
# ('Camera', 'Laptop', 'Headphones', 'Smartphone', 'Charger') -> ('Smartwatch',) (confidence: 0.35)
# ('Smartwatch',) -> ('Keyboard', 'Smartphone', 'Laptop', 'Headphones') (confidence: 0.57)
# ('Laptop',) -> ('Keyboard', 'Smartphone', 'Headphones', 'Smartwatch') (confidence: 0.68)
# ('Headphones',) -> ('Keyboard', 'Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.70)
# ('Smartphone',) -> ('Keyboard', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.72)
# ('Keyboard',) -> ('Smartphone', 'Laptop', 'Smartwatch', 'Headphones') (confidence: 0.72)
# ('Smartwatch', 'Laptop') -> ('Keyboard', 'Smartphone', 'Headphones') (confidence: 0.40)
# ('Smartwatch', 'Headphones') -> ('Keyboard', 'Smartphone', 'Laptop') (confidence: 0.47)
# ('Smartwatch', 'Smartphone') -> ('Keyboard', 'Laptop', 'Headphones') (confidence: 0.47)
# ('Smartwatch', 'Keyboard') -> ('Smartphone', 'Laptop', 'Headphones') (confidence: 0.50)
# ('Laptop', 'Headphones') -> ('Keyboard', 'Smartphone', 'Smartwatch') (confidence: 0.57)
# ('Laptop', 'Smartphone') -> ('Keyboard', 'Headphones', 'Smartwatch') (confidence: 0.60)
# ('Laptop', 'Keyboard') -> ('Smartphone', 'Headphones', 'Smartwatch') (confidence: 0.57)
# ('Headphones', 'Smartphone') -> ('Keyboard', 'Laptop', 'Smartwatch') (confidence: 0.60)
# ('Headphones', 'Keyboard') -> ('Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.57)
# ('Smartphone', 'Keyboard') -> ('Laptop', 'Smartwatch', 'Headphones') (confidence: 0.62)
# ('Smartwatch', 'Laptop', 'Headphones') -> ('Keyboard', 'Smartphone') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Smartphone') -> ('Keyboard', 'Headphones') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Keyboard') -> ('Smartphone', 'Headphones') (confidence: 0.40)
# ('Smartwatch', 'Headphones', 'Smartphone') -> ('Keyboard', 'Laptop') (confidence: 0.38)
# ('Smartwatch', 'Headphones', 'Keyboard') -> ('Smartphone', 'Laptop') (confidence: 0.42)
# ('Smartwatch', 'Smartphone', 'Keyboard') -> ('Laptop', 'Headphones') (confidence: 0.45)
# ('Laptop', 'Headphones', 'Smartphone') -> ('Keyboard', 'Smartwatch') (confidence: 0.53)
# ('Laptop', 'Headphones', 'Keyboard') -> ('Smartphone', 'Smartwatch') (confidence: 0.50)
# ('Laptop', 'Smartphone', 'Keyboard') -> ('Headphones', 'Smartwatch') (confidence: 0.53)
# ('Headphones', 'Smartphone', 'Keyboard') -> ('Laptop', 'Smartwatch') (confidence: 0.53)
# ('Smartwatch', 'Laptop', 'Headphones', 'Smartphone') -> ('Keyboard',) (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Headphones', 'Keyboard') -> ('Smartphone',) (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Keyboard') -> ('Headphones',) (confidence: 0.35)
# ('Smartwatch', 'Headphones', 'Smartphone', 'Keyboard') -> ('Laptop',) (confidence: 0.38)
# ('Laptop', 'Headphones', 'Smartphone', 'Keyboard') -> ('Smartwatch',) (confidence: 0.45)
# ('Laptop',) -> ('Monitor', 'Headphones', 'Speaker') (confidence: 0.68)
# ('Headphones',) -> ('Monitor', 'Laptop', 'Speaker') (confidence: 0.70)
# ('Monitor',) -> ('Headphones', 'Laptop', 'Speaker') (confidence: 0.68)
# ('Speaker',) -> ('Monitor', 'Laptop', 'Headphones') (confidence: 0.50)
# ('Laptop', 'Headphones') -> ('Monitor', 'Speaker') (confidence: 0.57)
# ('Laptop', 'Monitor') -> ('Headphones', 'Speaker') (confidence: 0.55)
# ('Laptop', 'Speaker') -> ('Monitor', 'Headphones') (confidence: 0.45)
# ('Headphones', 'Monitor') -> ('Laptop', 'Speaker') (confidence: 0.65)
# ('Headphones', 'Speaker') -> ('Monitor', 'Laptop') (confidence: 0.38)
# ('Monitor', 'Speaker') -> ('Laptop', 'Headphones') (confidence: 0.35)
# ('Laptop', 'Headphones', 'Monitor') -> ('Speaker',) (confidence: 0.53)
# ('Laptop', 'Headphones', 'Speaker') -> ('Monitor',) (confidence: 0.38)
# ('Laptop', 'Monitor', 'Speaker') -> ('Headphones',) (confidence: 0.35)
# ('Headphones', 'Monitor', 'Speaker') -> ('Laptop',) (confidence: 0.33)
# ('Mouse',) -> ('Keyboard', 'Camera', 'Headphones', 'Smartphone') (confidence: 0.57)
# ('Camera',) -> ('Mouse', 'Smartphone', 'Headphones', 'Keyboard') (confidence: 0.50)
# ('Headphones',) -> ('Keyboard', 'Mouse', 'Camera', 'Smartphone') (confidence: 0.70)
# ('Smartphone',) -> ('Mouse', 'Camera', 'Headphones', 'Keyboard') (confidence: 0.72)
# ('Keyboard',) -> ('Mouse', 'Camera', 'Headphones', 'Smartphone') (confidence: 0.72)
# ('Mouse', 'Camera') -> ('Keyboard', 'Smartphone', 'Headphones') (confidence: 0.42)
# ('Mouse', 'Headphones') -> ('Keyboard', 'Camera', 'Smartphone') (confidence: 0.47)
# ('Mouse', 'Smartphone') -> ('Keyboard', 'Camera', 'Headphones') (confidence: 0.47)
# ('Mouse', 'Keyboard') -> ('Camera', 'Headphones', 'Smartphone') (confidence: 0.47)
# ('Camera', 'Headphones') -> ('Mouse', 'Smartphone', 'Keyboard') (confidence: 0.40)
# ('Camera', 'Smartphone') -> ('Mouse', 'Keyboard', 'Headphones') (confidence: 0.42)
# ('Camera', 'Keyboard') -> ('Mouse', 'Smartphone', 'Headphones') (confidence: 0.47)
# ('Headphones', 'Smartphone') -> ('Mouse', 'Camera', 'Keyboard') (confidence: 0.60)
# ('Headphones', 'Keyboard') -> ('Mouse', 'Camera', 'Smartphone') (confidence: 0.57)
# ('Smartphone', 'Keyboard') -> ('Mouse', 'Camera', 'Headphones') (confidence: 0.62)
# ('Mouse', 'Camera', 'Headphones') -> ('Keyboard', 'Smartphone') (confidence: 0.35)
# ('Mouse', 'Camera', 'Smartphone') -> ('Keyboard', 'Headphones') (confidence: 0.35)
# ('Mouse', 'Camera', 'Keyboard') -> ('Smartphone', 'Headphones') (confidence: 0.40)
# ('Mouse', 'Headphones', 'Smartphone') -> ('Keyboard', 'Camera') (confidence: 0.42)
# ('Mouse', 'Headphones', 'Keyboard') -> ('Camera', 'Smartphone') (confidence: 0.42)
# ('Mouse', 'Smartphone', 'Keyboard') -> ('Camera', 'Headphones') (confidence: 0.42)
# ('Camera', 'Headphones', 'Smartphone') -> ('Mouse', 'Keyboard') (confidence: 0.35)
# ('Camera', 'Headphones', 'Keyboard') -> ('Mouse', 'Smartphone') (confidence: 0.40)
# ('Camera', 'Smartphone', 'Keyboard') -> ('Mouse', 'Headphones') (confidence: 0.42)
# ('Headphones', 'Smartphone', 'Keyboard') -> ('Mouse', 'Camera') (confidence: 0.53)
# ('Mouse', 'Camera', 'Headphones', 'Smartphone') -> ('Keyboard',) (confidence: 0.30)
# ('Mouse', 'Camera', 'Headphones', 'Keyboard') -> ('Smartphone',) (confidence: 0.35)
# ('Mouse', 'Camera', 'Smartphone', 'Keyboard') -> ('Headphones',) (confidence: 0.35)
# ('Mouse', 'Headphones', 'Smartphone', 'Keyboard') -> ('Camera',) (confidence: 0.38)
# ('Camera', 'Headphones', 'Smartphone', 'Keyboard') -> ('Mouse',) (confidence: 0.35)
# ('Laptop',) -> ('Charger', 'Keyboard', 'Monitor', 'Headphones') (confidence: 0.68)
# ('Headphones',) -> ('Charger', 'Keyboard', 'Monitor', 'Laptop') (confidence: 0.70)
# ('Monitor',) -> ('Charger', 'Keyboard', 'Laptop', 'Headphones') (confidence: 0.68)
# ('Keyboard',) -> ('Charger', 'Monitor', 'Laptop', 'Headphones') (confidence: 0.72)
# ('Charger',) -> ('Keyboard', 'Monitor', 'Laptop', 'Headphones') (confidence: 0.55)
# ('Laptop', 'Headphones') -> ('Keyboard', 'Monitor', 'Charger') (confidence: 0.57)
# ('Laptop', 'Monitor') -> ('Charger', 'Keyboard', 'Headphones') (confidence: 0.55)
# ('Laptop', 'Keyboard') -> ('Charger', 'Monitor', 'Headphones') (confidence: 0.57)
# ('Laptop', 'Charger') -> ('Keyboard', 'Monitor', 'Headphones') (confidence: 0.53)
# ('Headphones', 'Monitor') -> ('Charger', 'Keyboard', 'Laptop') (confidence: 0.65)
# ('Headphones', 'Keyboard') -> ('Charger', 'Monitor', 'Laptop') (confidence: 0.57)
# ('Headphones', 'Charger') -> ('Keyboard', 'Monitor', 'Laptop') (confidence: 0.45)
# ('Monitor', 'Keyboard') -> ('Charger', 'Laptop', 'Headphones') (confidence: 0.55)
# ('Monitor', 'Charger') -> ('Keyboard', 'Laptop', 'Headphones') (confidence: 0.42)
# ('Keyboard', 'Charger') -> ('Monitor', 'Laptop', 'Headphones') (confidence: 0.53)
# ('Laptop', 'Headphones', 'Monitor') -> ('Keyboard', 'Charger') (confidence: 0.53)
# ('Laptop', 'Headphones', 'Keyboard') -> ('Monitor', 'Charger') (confidence: 0.50)
# ('Laptop', 'Headphones', 'Charger') -> ('Keyboard', 'Monitor') (confidence: 0.45)
# ('Laptop', 'Monitor', 'Keyboard') -> ('Charger', 'Headphones') (confidence: 0.47)
# ('Laptop', 'Monitor', 'Charger') -> ('Keyboard', 'Headphones') (confidence: 0.42)
# ('Laptop', 'Keyboard', 'Charger') -> ('Monitor', 'Headphones') (confidence: 0.53)
# ('Headphones', 'Monitor', 'Keyboard') -> ('Charger', 'Laptop') (confidence: 0.53)
# ('Headphones', 'Monitor', 'Charger') -> ('Keyboard', 'Laptop') (confidence: 0.40)
# ('Headphones', 'Keyboard', 'Charger') -> ('Monitor', 'Laptop') (confidence: 0.45)
# ('Monitor', 'Keyboard', 'Charger') -> ('Laptop', 'Headphones') (confidence: 0.42)
# ('Laptop', 'Headphones', 'Monitor', 'Keyboard') -> ('Charger',) (confidence: 0.45)
# ('Laptop', 'Headphones', 'Monitor', 'Charger') -> ('Keyboard',) (confidence: 0.40)
# ('Laptop', 'Headphones', 'Keyboard', 'Charger') -> ('Monitor',) (confidence: 0.45)
# ('Laptop', 'Monitor', 'Keyboard', 'Charger') -> ('Headphones',) (confidence: 0.42)
# ('Headphones', 'Monitor', 'Keyboard', 'Charger') -> ('Laptop',) (confidence: 0.40)
# ('Laptop',) -> ('Monitor', 'Smartphone', 'Speaker', 'Keyboard', 'Charger') (confidence: 0.68)
# ('Monitor',) -> ('Smartphone', 'Laptop', 'Speaker', 'Keyboard', 'Charger') (confidence: 0.68)
# ('Smartphone',) -> ('Monitor', 'Laptop', 'Speaker', 'Keyboard', 'Charger') (confidence: 0.72)
# ('Speaker',) -> ('Monitor', 'Laptop', 'Smartphone', 'Keyboard', 'Charger') (confidence: 0.50)
# ('Keyboard',) -> ('Monitor', 'Laptop', 'Smartphone', 'Speaker', 'Charger') (confidence: 0.72)
# ('Charger',) -> ('Monitor', 'Laptop', 'Smartphone', 'Speaker', 'Keyboard') (confidence: 0.55)
# ('Laptop', 'Monitor') -> ('Keyboard', 'Smartphone', 'Charger', 'Speaker') (confidence: 0.55)
# ('Laptop', 'Smartphone') -> ('Keyboard', 'Monitor', 'Charger', 'Speaker') (confidence: 0.60)
# ('Laptop', 'Speaker') -> ('Keyboard', 'Monitor', 'Charger', 'Smartphone') (confidence: 0.45)
# ('Laptop', 'Keyboard') -> ('Monitor', 'Charger', 'Speaker', 'Smartphone') (confidence: 0.57)
# ('Laptop', 'Charger') -> ('Keyboard', 'Monitor', 'Speaker', 'Smartphone') (confidence: 0.53)
# ('Monitor', 'Smartphone') -> ('Charger', 'Keyboard', 'Laptop', 'Speaker') (confidence: 0.57)
# ('Monitor', 'Speaker') -> ('Charger', 'Keyboard', 'Smartphone', 'Laptop') (confidence: 0.35)
# ('Monitor', 'Keyboard') -> ('Charger', 'Smartphone', 'Laptop', 'Speaker') (confidence: 0.55)
# ('Monitor', 'Charger') -> ('Keyboard', 'Smartphone', 'Laptop', 'Speaker') (confidence: 0.42)
# ('Smartphone', 'Speaker') -> ('Charger', 'Keyboard', 'Monitor', 'Laptop') (confidence: 0.40)
# ('Smartphone', 'Keyboard') -> ('Charger', 'Monitor', 'Laptop', 'Speaker') (confidence: 0.62)
# ('Smartphone', 'Charger') -> ('Keyboard', 'Monitor', 'Laptop', 'Speaker') (confidence: 0.55)
# ('Speaker', 'Keyboard') -> ('Charger', 'Monitor', 'Laptop', 'Smartphone') (confidence: 0.42)
# ('Speaker', 'Charger') -> ('Keyboard', 'Monitor', 'Laptop', 'Smartphone') (confidence: 0.38)
# ('Keyboard', 'Charger') -> ('Monitor', 'Laptop', 'Speaker', 'Smartphone') (confidence: 0.53)
# ('Laptop', 'Monitor', 'Smartphone') -> ('Keyboard', 'Charger', 'Speaker') (confidence: 0.50)
# ('Laptop', 'Monitor', 'Speaker') -> ('Keyboard', 'Smartphone', 'Charger') (confidence: 0.35)
# ('Laptop', 'Monitor', 'Keyboard') -> ('Smartphone', 'Charger', 'Speaker') (confidence: 0.47)
# ('Laptop', 'Monitor', 'Charger') -> ('Keyboard', 'Smartphone', 'Speaker') (confidence: 0.42)
# ('Laptop', 'Smartphone', 'Speaker') -> ('Keyboard', 'Monitor', 'Charger') (confidence: 0.40)
# ('Laptop', 'Smartphone', 'Keyboard') -> ('Monitor', 'Charger', 'Speaker') (confidence: 0.53)
# ('Laptop', 'Smartphone', 'Charger') -> ('Keyboard', 'Monitor', 'Speaker') (confidence: 0.53)
# ('Laptop', 'Speaker', 'Keyboard') -> ('Monitor', 'Charger', 'Smartphone') (confidence: 0.42)
# ('Laptop', 'Speaker', 'Charger') -> ('Keyboard', 'Monitor', 'Smartphone') (confidence: 0.38)
# ('Laptop', 'Keyboard', 'Charger') -> ('Monitor', 'Speaker', 'Smartphone') (confidence: 0.53)
# ('Monitor', 'Smartphone', 'Speaker') -> ('Charger', 'Keyboard', 'Laptop') (confidence: 0.30)
# ('Monitor', 'Smartphone', 'Keyboard') -> ('Charger', 'Laptop', 'Speaker') (confidence: 0.50)
# ('Monitor', 'Smartphone', 'Charger') -> ('Keyboard', 'Laptop', 'Speaker') (confidence: 0.42)
# ('Monitor', 'Speaker', 'Keyboard') -> ('Charger', 'Smartphone', 'Laptop') (confidence: 0.33)
# ('Monitor', 'Keyboard', 'Charger') -> ('Smartphone', 'Laptop', 'Speaker') (confidence: 0.42)
# ('Smartphone', 'Speaker', 'Keyboard') -> ('Charger', 'Monitor', 'Laptop') (confidence: 0.38)
# ('Smartphone', 'Speaker', 'Charger') -> ('Keyboard', 'Monitor', 'Laptop') (confidence: 0.38)
# ('Smartphone', 'Keyboard', 'Charger') -> ('Monitor', 'Laptop', 'Speaker') (confidence: 0.53)
# ('Speaker', 'Keyboard', 'Charger') -> ('Monitor', 'Laptop', 'Smartphone') (confidence: 0.38)
# ('Laptop', 'Monitor', 'Smartphone', 'Speaker') -> ('Keyboard', 'Charger') (confidence: 0.30)
# ('Laptop', 'Monitor', 'Smartphone', 'Keyboard') -> ('Charger', 'Speaker') (confidence: 0.42)
# ('Laptop', 'Monitor', 'Smartphone', 'Charger') -> ('Keyboard', 'Speaker') (confidence: 0.42)
# ('Laptop', 'Monitor', 'Speaker', 'Keyboard') -> ('Smartphone', 'Charger') (confidence: 0.33)
# ('Laptop', 'Monitor', 'Keyboard', 'Charger') -> ('Smartphone', 'Speaker') (confidence: 0.42)
# ('Laptop', 'Smartphone', 'Speaker', 'Keyboard') -> ('Monitor', 'Charger') (confidence: 0.38)
# ('Laptop', 'Smartphone', 'Speaker', 'Charger') -> ('Keyboard', 'Monitor') (confidence: 0.38)
# ('Laptop', 'Smartphone', 'Keyboard', 'Charger') -> ('Monitor', 'Speaker') (confidence: 0.53)
# ('Laptop', 'Speaker', 'Keyboard', 'Charger') -> ('Monitor', 'Smartphone') (confidence: 0.38)
# ('Monitor', 'Smartphone', 'Keyboard', 'Charger') -> ('Laptop', 'Speaker') (confidence: 0.42)
# ('Smartphone', 'Speaker', 'Keyboard', 'Charger') -> ('Monitor', 'Laptop') (confidence: 0.38)
# ('Laptop', 'Monitor', 'Smartphone', 'Keyboard', 'Charger') -> ('Speaker',) (confidence: 0.42)
# ('Laptop', 'Smartphone', 'Speaker', 'Keyboard', 'Charger') -> ('Monitor',) (confidence: 0.38)
# ('Mouse',) -> ('Monitor', 'Headphones', 'Smartphone', 'Keyboard', 'Charger') (confidence: 0.57)
# ('Headphones',) -> ('Mouse', 'Monitor', 'Smartphone', 'Keyboard', 'Charger') (confidence: 0.70)
# ('Monitor',) -> ('Mouse', 'Smartphone', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.68)
# ('Smartphone',) -> ('Mouse', 'Monitor', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.72)
# ('Keyboard',) -> ('Mouse', 'Monitor', 'Headphones', 'Smartphone', 'Charger') (confidence: 0.72)
# ('Charger',) -> ('Mouse', 'Monitor', 'Headphones', 'Smartphone', 'Keyboard') (confidence: 0.55)
# ('Mouse', 'Headphones') -> ('Keyboard', 'Monitor', 'Charger', 'Smartphone') (confidence: 0.47)
# ('Mouse', 'Monitor') -> ('Charger', 'Keyboard', 'Smartphone', 'Headphones') (confidence: 0.42)
# ('Mouse', 'Smartphone') -> ('Charger', 'Keyboard', 'Monitor', 'Headphones') (confidence: 0.47)
# ('Mouse', 'Keyboard') -> ('Charger', 'Monitor', 'Headphones', 'Smartphone') (confidence: 0.47)
# ('Mouse', 'Charger') -> ('Keyboard', 'Monitor', 'Headphones', 'Smartphone') (confidence: 0.35)
# ('Headphones', 'Monitor') -> ('Mouse', 'Smartphone', 'Charger', 'Keyboard') (confidence: 0.65)
# ('Headphones', 'Smartphone') -> ('Mouse', 'Monitor', 'Charger', 'Keyboard') (confidence: 0.60)
# ('Headphones', 'Keyboard') -> ('Mouse', 'Monitor', 'Charger', 'Smartphone') (confidence: 0.57)
# ('Headphones', 'Charger') -> ('Keyboard', 'Mouse', 'Monitor', 'Smartphone') (confidence: 0.45)
# ('Monitor', 'Smartphone') -> ('Charger', 'Mouse', 'Keyboard', 'Headphones') (confidence: 0.57)
# ('Monitor', 'Keyboard') -> ('Charger', 'Mouse', 'Smartphone', 'Headphones') (confidence: 0.55)
# ('Monitor', 'Charger') -> ('Mouse', 'Smartphone', 'Headphones', 'Keyboard') (confidence: 0.42)
# ('Smartphone', 'Keyboard') -> ('Charger', 'Mouse', 'Monitor', 'Headphones') (confidence: 0.62)
# ('Smartphone', 'Charger') -> ('Mouse', 'Monitor', 'Headphones', 'Keyboard') (confidence: 0.55)
# ('Keyboard', 'Charger') -> ('Mouse', 'Monitor', 'Headphones', 'Smartphone') (confidence: 0.53)
# ('Mouse', 'Headphones', 'Monitor') -> ('Keyboard', 'Smartphone', 'Charger') (confidence: 0.42)
# ('Mouse', 'Headphones', 'Smartphone') -> ('Keyboard', 'Monitor', 'Charger') (confidence: 0.42)
# ('Mouse', 'Headphones', 'Keyboard') -> ('Monitor', 'Charger', 'Smartphone') (confidence: 0.42)
# ('Mouse', 'Headphones', 'Charger') -> ('Keyboard', 'Monitor', 'Smartphone') (confidence: 0.30)
# ('Mouse', 'Monitor', 'Smartphone') -> ('Charger', 'Keyboard', 'Headphones') (confidence: 0.38)
# ('Mouse', 'Monitor', 'Keyboard') -> ('Charger', 'Smartphone', 'Headphones') (confidence: 0.38)
# ('Mouse', 'Smartphone', 'Keyboard') -> ('Charger', 'Monitor', 'Headphones') (confidence: 0.42)
# ('Mouse', 'Smartphone', 'Charger') -> ('Keyboard', 'Monitor', 'Headphones') (confidence: 0.35)
# ('Mouse', 'Keyboard', 'Charger') -> ('Monitor', 'Headphones', 'Smartphone') (confidence: 0.35)
# ('Headphones', 'Monitor', 'Smartphone') -> ('Mouse', 'Keyboard', 'Charger') (confidence: 0.55)
# ('Headphones', 'Monitor', 'Keyboard') -> ('Mouse', 'Smartphone', 'Charger') (confidence: 0.53)
# ('Headphones', 'Monitor', 'Charger') -> ('Mouse', 'Smartphone', 'Keyboard') (confidence: 0.40)
# ('Headphones', 'Smartphone', 'Keyboard') -> ('Mouse', 'Monitor', 'Charger') (confidence: 0.53)
# ('Headphones', 'Smartphone', 'Charger') -> ('Mouse', 'Monitor', 'Keyboard') (confidence: 0.45)
# ('Headphones', 'Keyboard', 'Charger') -> ('Mouse', 'Monitor', 'Smartphone') (confidence: 0.45)
# ('Monitor', 'Smartphone', 'Keyboard') -> ('Charger', 'Mouse', 'Headphones') (confidence: 0.50)
# ('Monitor', 'Smartphone', 'Charger') -> ('Mouse', 'Keyboard', 'Headphones') (confidence: 0.42)
# ('Monitor', 'Keyboard', 'Charger') -> ('Mouse', 'Smartphone', 'Headphones') (confidence: 0.42)
# ('Smartphone', 'Keyboard', 'Charger') -> ('Mouse', 'Monitor', 'Headphones') (confidence: 0.53)
# ('Mouse', 'Headphones', 'Monitor', 'Smartphone') -> ('Keyboard', 'Charger') (confidence: 0.38)
# ('Mouse', 'Headphones', 'Monitor', 'Keyboard') -> ('Smartphone', 'Charger') (confidence: 0.38)
# ('Mouse', 'Headphones', 'Smartphone', 'Keyboard') -> ('Monitor', 'Charger') (confidence: 0.38)
# ('Mouse', 'Headphones', 'Smartphone', 'Charger') -> ('Keyboard', 'Monitor') (confidence: 0.30)
# ('Mouse', 'Headphones', 'Keyboard', 'Charger') -> ('Monitor', 'Smartphone') (confidence: 0.30)
# ('Mouse', 'Monitor', 'Smartphone', 'Keyboard') -> ('Charger', 'Headphones') (confidence: 0.33)
# ('Mouse', 'Smartphone', 'Keyboard', 'Charger') -> ('Monitor', 'Headphones') (confidence: 0.35)
# ('Headphones', 'Monitor', 'Smartphone', 'Keyboard') -> ('Mouse', 'Charger') (confidence: 0.47)
# ('Headphones', 'Monitor', 'Smartphone', 'Charger') -> ('Mouse', 'Keyboard') (confidence: 0.40)
# ('Headphones', 'Monitor', 'Keyboard', 'Charger') -> ('Mouse', 'Smartphone') (confidence: 0.40)
# ('Headphones', 'Smartphone', 'Keyboard', 'Charger') -> ('Mouse', 'Monitor') (confidence: 0.45)
# ('Monitor', 'Smartphone', 'Keyboard', 'Charger') -> ('Mouse', 'Headphones') (confidence: 0.42)
# ('Mouse', 'Headphones', 'Monitor', 'Smartphone', 'Keyboard') -> ('Charger',) (confidence: 0.33)
# ('Mouse', 'Headphones', 'Smartphone', 'Keyboard', 'Charger') -> ('Monitor',) (confidence: 0.30)
# ('Headphones', 'Monitor', 'Smartphone', 'Keyboard', 'Charger') -> ('Mouse',) (confidence: 0.40)
# ('Smartwatch',) -> ('Smartphone', 'Laptop', 'nan', 'Keyboard', 'Charger') (confidence: 0.57)
# ('Laptop',) -> ('Smartwatch', 'Smartphone', 'nan', 'Keyboard', 'Charger') (confidence: 0.68)
# ('Smartphone',) -> ('Smartwatch', 'Laptop', 'nan', 'Keyboard', 'Charger') (confidence: 0.72)
# ('nan',) -> ('Smartwatch', 'Smartphone', 'Laptop', 'Keyboard', 'Charger') (confidence: 0.90)
# ('Keyboard',) -> ('Smartwatch', 'Smartphone', 'Laptop', 'nan', 'Charger') (confidence: 0.72)
# ('Charger',) -> ('Smartwatch', 'Smartphone', 'Laptop', 'nan', 'Keyboard') (confidence: 0.55)
# ('Smartwatch', 'Laptop') -> ('Keyboard', 'Smartphone', 'Charger', 'nan') (confidence: 0.40)
# ('Smartwatch', 'Smartphone') -> ('Charger', 'Keyboard', 'Laptop', 'nan') (confidence: 0.47)
# ('Smartwatch', 'nan') -> ('Charger', 'Keyboard', 'Smartphone', 'Laptop') (confidence: 0.47)
# ('Smartwatch', 'Keyboard') -> ('Charger', 'Smartphone', 'Laptop', 'nan') (confidence: 0.50)
# ('Smartwatch', 'Charger') -> ('Keyboard', 'Smartphone', 'Laptop', 'nan') (confidence: 0.38)
# ('Laptop', 'Smartphone') -> ('Keyboard', 'Charger', 'Smartwatch', 'nan') (confidence: 0.60)
# ('Laptop', 'nan') -> ('Keyboard', 'Smartphone', 'Charger', 'Smartwatch') (confidence: 0.57)
# ('Laptop', 'Keyboard') -> ('Smartphone', 'Charger', 'Smartwatch', 'nan') (confidence: 0.57)
# ('Laptop', 'Charger') -> ('Keyboard', 'Smartphone', 'Smartwatch', 'nan') (confidence: 0.53)
# ('Smartphone', 'nan') -> ('Charger', 'Keyboard', 'Laptop', 'Smartwatch') (confidence: 0.62)
# ('Smartphone', 'Keyboard') -> ('Charger', 'Laptop', 'Smartwatch', 'nan') (confidence: 0.62)
# ('Smartphone', 'Charger') -> ('Keyboard', 'Laptop', 'Smartwatch', 'nan') (confidence: 0.55)
# ('nan', 'Keyboard') -> ('Charger', 'Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.62)
# ('nan', 'Charger') -> ('Keyboard', 'Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.45)
# ('Keyboard', 'Charger') -> ('Smartphone', 'Laptop', 'Smartwatch', 'nan') (confidence: 0.53)
# ('Smartwatch', 'Laptop', 'Smartphone') -> ('Keyboard', 'Charger', 'nan') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'nan') -> ('Keyboard', 'Smartphone', 'Charger') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Keyboard') -> ('Smartphone', 'Charger', 'nan') (confidence: 0.40)
# ('Smartwatch', 'Laptop', 'Charger') -> ('Keyboard', 'Smartphone', 'nan') (confidence: 0.35)
# ('Smartwatch', 'Smartphone', 'nan') -> ('Charger', 'Keyboard', 'Laptop') (confidence: 0.38)
# ('Smartwatch', 'Smartphone', 'Keyboard') -> ('Charger', 'Laptop', 'nan') (confidence: 0.45)
# ('Smartwatch', 'Smartphone', 'Charger') -> ('Keyboard', 'Laptop', 'nan') (confidence: 0.38)
# ('Smartwatch', 'nan', 'Keyboard') -> ('Charger', 'Smartphone', 'Laptop') (confidence: 0.40)
# ('Smartwatch', 'Keyboard', 'Charger') -> ('Smartphone', 'Laptop', 'nan') (confidence: 0.35)
# ('Laptop', 'Smartphone', 'nan') -> ('Keyboard', 'Charger', 'Smartwatch') (confidence: 0.50)
# ('Laptop', 'Smartphone', 'Keyboard') -> ('Charger', 'Smartwatch', 'nan') (confidence: 0.53)
# ('Laptop', 'Smartphone', 'Charger') -> ('Keyboard', 'Smartwatch', 'nan') (confidence: 0.53)
# ('Laptop', 'nan', 'Keyboard') -> ('Smartphone', 'Charger', 'Smartwatch') (confidence: 0.47)
# ('Laptop', 'nan', 'Charger') -> ('Keyboard', 'Smartphone', 'Smartwatch') (confidence: 0.42)
# ('Laptop', 'Keyboard', 'Charger') -> ('Smartphone', 'Smartwatch', 'nan') (confidence: 0.53)
# ('Smartphone', 'nan', 'Keyboard') -> ('Charger', 'Laptop', 'Smartwatch') (confidence: 0.53)
# ('Smartphone', 'nan', 'Charger') -> ('Keyboard', 'Laptop', 'Smartwatch') (confidence: 0.45)
# ('Smartphone', 'Keyboard', 'Charger') -> ('Laptop', 'Smartwatch', 'nan') (confidence: 0.53)
# ('nan', 'Keyboard', 'Charger') -> ('Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.42)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Keyboard') -> ('Charger', 'nan') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Charger') -> ('Keyboard', 'nan') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'nan', 'Keyboard') -> ('Smartphone', 'Charger') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Keyboard', 'Charger') -> ('Smartphone', 'nan') (confidence: 0.35)
# ('Smartwatch', 'Smartphone', 'nan', 'Keyboard') -> ('Charger', 'Laptop') (confidence: 0.35)
# ('Smartwatch', 'Smartphone', 'Keyboard', 'Charger') -> ('Laptop', 'nan') (confidence: 0.35)
# ('Laptop', 'Smartphone', 'nan', 'Keyboard') -> ('Charger', 'Smartwatch') (confidence: 0.42)
# ('Laptop', 'Smartphone', 'nan', 'Charger') -> ('Keyboard', 'Smartwatch') (confidence: 0.42)
# ('Laptop', 'Smartphone', 'Keyboard', 'Charger') -> ('Smartwatch', 'nan') (confidence: 0.53)
# ('Laptop', 'nan', 'Keyboard', 'Charger') -> ('Smartphone', 'Smartwatch') (confidence: 0.42)
# ('Smartphone', 'nan', 'Keyboard', 'Charger') -> ('Laptop', 'Smartwatch') (confidence: 0.42)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Keyboard', 'Charger') -> ('nan',) (confidence: 0.35)
# ('Laptop', 'Smartphone', 'nan', 'Keyboard', 'Charger') -> ('Smartwatch',) (confidence: 0.42)
# ('Mouse',) -> ('Smartphone', 'Laptop', 'nan', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.57)
# ('Laptop',) -> ('Mouse', 'Smartphone', 'Headphones', 'nan', 'Keyboard', 'Charger') (confidence: 0.68)
# ('Headphones',) -> ('Mouse', 'Smartphone', 'Laptop', 'nan', 'Keyboard', 'Charger') (confidence: 0.70)
# ('Smartphone',) -> ('Mouse', 'Laptop', 'nan', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.72)
# ('nan',) -> ('Mouse', 'Smartphone', 'Laptop', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.90)
# ('Keyboard',) -> ('Mouse', 'Smartphone', 'Laptop', 'nan', 'Headphones', 'Charger') (confidence: 0.72)
# ('Charger',) -> ('Mouse', 'Smartphone', 'Laptop', 'nan', 'Headphones', 'Keyboard') (confidence: 0.55)
# ('Mouse', 'Laptop') -> ('Smartphone', 'Headphones', 'nan', 'Keyboard', 'Charger') (confidence: 0.45)
# ('Mouse', 'Headphones') -> ('Smartphone', 'Laptop', 'nan', 'Keyboard', 'Charger') (confidence: 0.47)
# ('Mouse', 'Smartphone') -> ('Laptop', 'nan', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.47)
# ('Mouse', 'nan') -> ('Smartphone', 'Laptop', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.47)
# ('Mouse', 'Keyboard') -> ('Smartphone', 'Laptop', 'nan', 'Headphones', 'Charger') (confidence: 0.47)
# ('Mouse', 'Charger') -> ('Smartphone', 'Laptop', 'nan', 'Headphones', 'Keyboard') (confidence: 0.35)
# ('Laptop', 'Headphones') -> ('Mouse', 'Smartphone', 'nan', 'Keyboard', 'Charger') (confidence: 0.57)
# ('Laptop', 'Smartphone') -> ('Mouse', 'Headphones', 'nan', 'Keyboard', 'Charger') (confidence: 0.60)
# ('Laptop', 'nan') -> ('Mouse', 'Smartphone', 'Headphones', 'Keyboard', 'Charger') (confidence: 0.57)
# ('Laptop', 'Keyboard') -> ('Mouse', 'Smartphone', 'Headphones', 'nan', 'Charger') (confidence: 0.57)
# ('Laptop', 'Charger') -> ('Mouse', 'Smartphone', 'Headphones', 'nan', 'Keyboard') (confidence: 0.53)
# ('Headphones', 'Smartphone') -> ('Mouse', 'Laptop', 'nan', 'Keyboard', 'Charger') (confidence: 0.60)
# ('Headphones', 'nan') -> ('Mouse', 'Smartphone', 'Laptop', 'Keyboard', 'Charger') (confidence: 0.60)
# ...
# ('Mouse', 'Smartphone') -> ('Smartwatch', 'Camera', 'Laptop', 'Speaker', 'Keyboard') (confidence: 0.47)
# ('Mouse', 'Keyboard') -> ('Smartwatch', 'Camera', 'Laptop', 'Smartphone', 'Speaker') (confidence: 0.47)
# ('Camera', 'Laptop') -> ('Smartwatch', 'Mouse', 'Smartphone', 'Speaker', 'Keyboard') (confidence: 0.47)
# ('Camera', 'Smartphone') -> ('Smartwatch', 'Mouse', 'Laptop', 'Speaker', 'Keyboard') (confidence: 0.42)
# ('Camera', 'Speaker') -> ('Smartwatch', 'Mouse', 'Smartphone', 'Laptop', 'Keyboard') (confidence: 0.33)
# ('Camera', 'Keyboard') -> ('Smartwatch', 'Mouse', 'Smartphone', 'Laptop', 'Speaker') (confidence: 0.47)
# ('Laptop', 'Smartphone') -> ('Smartwatch', 'Mouse', 'Camera', 'Speaker', 'Keyboard') (confidence: 0.60)
# ('Laptop', 'Speaker') -> ('Smartwatch', 'Mouse', 'Camera', 'Smartphone', 'Keyboard') (confidence: 0.45)
# ('Laptop', 'Keyboard') -> ('Smartwatch', 'Mouse', 'Camera', 'Smartphone', 'Speaker') (confidence: 0.57)
# ('Smartphone', 'Speaker') -> ('Smartwatch', 'Mouse', 'Camera', 'Laptop', 'Keyboard') (confidence: 0.40)
# ('Smartphone', 'Keyboard') -> ('Smartwatch', 'Mouse', 'Camera', 'Laptop', 'Speaker') (confidence: 0.62)
# ('Speaker', 'Keyboard') -> ('Smartwatch', 'Mouse', 'Camera', 'Laptop', 'Smartphone') (confidence: 0.42)
# ('Smartwatch', 'Mouse', 'Keyboard') -> ('Camera', 'Laptop', 'Speaker', 'Smartphone') (confidence: 0.33)
# ('Smartwatch', 'Camera', 'Laptop') -> ('Mouse', 'Smartphone', 'Speaker', 'Keyboard') (confidence: 0.30)
# ('Smartwatch', 'Camera', 'Speaker') -> ('Mouse', 'Smartphone', 'Laptop', 'Keyboard') (confidence: 0.30)
# ('Smartwatch', 'Camera', 'Keyboard') -> ('Mouse', 'Smartphone', 'Laptop', 'Speaker') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Smartphone') -> ('Mouse', 'Camera', 'Speaker', 'Keyboard') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Speaker') -> ('Keyboard', 'Mouse', 'Camera', 'Smartphone') (confidence: 0.40)
# ('Smartwatch', 'Laptop', 'Keyboard') -> ('Mouse', 'Camera', 'Speaker', 'Smartphone') (confidence: 0.40)
# ('Smartwatch', 'Smartphone', 'Speaker') -> ('Mouse', 'Camera', 'Laptop', 'Keyboard') (confidence: 0.35)
# ('Smartwatch', 'Smartphone', 'Keyboard') -> ('Mouse', 'Camera', 'Laptop', 'Speaker') (confidence: 0.45)
# ('Smartwatch', 'Speaker', 'Keyboard') -> ('Mouse', 'Camera', 'Laptop', 'Smartphone') (confidence: 0.40)
# ('Mouse', 'Camera', 'Laptop') -> ('Keyboard', 'Smartphone', 'Smartwatch', 'Speaker') (confidence: 0.40)
# ('Mouse', 'Camera', 'Smartphone') -> ('Keyboard', 'Laptop', 'Smartwatch', 'Speaker') (confidence: 0.35)
# ('Mouse', 'Camera', 'Keyboard') -> ('Smartphone', 'Laptop', 'Smartwatch', 'Speaker') (confidence: 0.40)
# ('Mouse', 'Laptop', 'Smartphone') -> ('Keyboard', 'Camera', 'Smartwatch', 'Speaker') (confidence: 0.40)
# ('Mouse', 'Laptop', 'Keyboard') -> ('Camera', 'Smartwatch', 'Speaker', 'Smartphone') (confidence: 0.40)
# ('Mouse', 'Smartphone', 'Keyboard') -> ('Camera', 'Laptop', 'Smartwatch', 'Speaker') (confidence: 0.42)
# ('Camera', 'Laptop', 'Smartphone') -> ('Mouse', 'Keyboard', 'Smartwatch', 'Speaker') (confidence: 0.42)
# ('Camera', 'Laptop', 'Speaker') -> ('Mouse', 'Smartphone', 'Smartwatch', 'Keyboard') (confidence: 0.33)
# ('Camera', 'Laptop', 'Keyboard') -> ('Mouse', 'Smartphone', 'Smartwatch', 'Speaker') (confidence: 0.47)
# ('Camera', 'Smartphone', 'Keyboard') -> ('Mouse', 'Laptop', 'Smartwatch', 'Speaker') (confidence: 0.42)
# ('Camera', 'Speaker', 'Keyboard') -> ('Mouse', 'Smartphone', 'Laptop', 'Smartwatch') (confidence: 0.33)
# ('Laptop', 'Smartphone', 'Speaker') -> ('Mouse', 'Camera', 'Smartwatch', 'Keyboard') (confidence: 0.40)
# ('Laptop', 'Smartphone', 'Keyboard') -> ('Mouse', 'Camera', 'Smartwatch', 'Speaker') (confidence: 0.53)
# ('Laptop', 'Speaker', 'Keyboard') -> ('Mouse', 'Camera', 'Smartwatch', 'Smartphone') (confidence: 0.42)
# ('Smartphone', 'Speaker', 'Keyboard') -> ('Mouse', 'Camera', 'Laptop', 'Smartwatch') (confidence: 0.38)
# ('Smartwatch', 'Camera', 'Laptop', 'Speaker') -> ('Mouse', 'Smartphone', 'Keyboard') (confidence: 0.30)
# ('Smartwatch', 'Camera', 'Laptop', 'Keyboard') -> ('Mouse', 'Smartphone', 'Speaker') (confidence: 0.30)
# ('Smartwatch', 'Camera', 'Speaker', 'Keyboard') -> ('Mouse', 'Smartphone', 'Laptop') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Speaker') -> ('Mouse', 'Camera', 'Keyboard') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Keyboard') -> ('Mouse', 'Camera', 'Speaker') (confidence: 0.35)
# ('Smartwatch', 'Laptop', 'Speaker', 'Keyboard') -> ('Mouse', 'Camera', 'Smartphone') (confidence: 0.40)
# ('Smartwatch', 'Smartphone', 'Speaker', 'Keyboard') -> ('Mouse', 'Camera', 'Laptop') (confidence: 0.35)
# ('Mouse', 'Camera', 'Laptop', 'Smartphone') -> ('Keyboard', 'Smartwatch', 'Speaker') (confidence: 0.35)
# ('Mouse', 'Camera', 'Laptop', 'Keyboard') -> ('Smartphone', 'Smartwatch', 'Speaker') (confidence: 0.40)
# ('Mouse', 'Camera', 'Smartphone', 'Keyboard') -> ('Laptop', 'Smartwatch', 'Speaker') (confidence: 0.35)
# ('Mouse', 'Laptop', 'Smartphone', 'Keyboard') -> ('Camera', 'Smartwatch', 'Speaker') (confidence: 0.35)
# ('Camera', 'Laptop', 'Smartphone', 'Keyboard') -> ('Mouse', 'Smartwatch', 'Speaker') (confidence: 0.42)
# ('Camera', 'Laptop', 'Speaker', 'Keyboard') -> ('Mouse', 'Smartphone', 'Smartwatch') (confidence: 0.33)
# ('Laptop', 'Smartphone', 'Speaker', 'Keyboard') -> ('Mouse', 'Camera', 'Smartwatch') (confidence: 0.38)
# ('Smartwatch', 'Camera', 'Laptop', 'Speaker', 'Keyboard') -> ('Mouse', 'Smartphone') (confidence: 0.30)
# ('Smartwatch', 'Laptop', 'Smartphone', 'Speaker', 'Keyboard') -> ('Mouse', 'Camera') (confidence: 0.35)
# ('Mouse', 'Camera', 'Laptop', 'Smartphone', 'Keyboard') -> ('Smartwatch', 'Speaker') (confidence: 0.35)
# ('Mouse',) -> ('Camera', 'Headphones', 'nan', 'Smartphone', 'Keyboard') (confidence: 0.57)
# ('Camera',) -> ('Mouse', 'Smartphone', 'Headphones', 'nan', 'Keyboard') (confidence: 0.50)
# ('Headphones',) -> ('Mouse', 'Camera', 'Smartphone', 'nan', 'Keyboard') (confidence: 0.70)
# ('Smartphone',) -> ('Mouse', 'Camera', 'Headphones', 'nan', 'Keyboard') (confidence: 0.72)
# ('nan',) -> ('Mouse', 'Camera', 'Headphones', 'Smartphone', 'Keyboard') (confidence: 0.90)
# ('Keyboard',) -> ('Mouse', 'Camera', 'Headphones', 'nan', 'Smartphone') (confidence: 0.72)
# ('Mouse', 'Camera') -> ('Keyboard', 'Smartphone', 'Headphones', 'nan') (confidence: 0.42)
# ('Mouse', 'Headphones') -> ('Keyboard', 'Camera', 'nan', 'Smartphone') (confidence: 0.47)
# ('Mouse', 'Smartphone') -> ('Keyboard', 'Camera', 'Headphones', 'nan') (confidence: 0.47)
# ('Mouse', 'nan') -> ('Keyboard', 'Camera', 'Headphones', 'Smartphone') (confidence: 0.47)
# ('Mouse', 'Keyboard') -> ('Camera', 'Headphones', 'nan', 'Smartphone') (confidence: 0.47)
# ('Camera', 'Headphones') -> ('Mouse', 'Smartphone', 'nan', 'Keyboard') (confidence: 0.40)
# ('Camera', 'Smartphone') -> ('Mouse', 'Keyboard', 'Headphones', 'nan') (confidence: 0.42)
# ('Camera', 'nan') -> ('Mouse', 'Smartphone', 'Headphones', 'Keyboard') (confidence: 0.40)
# ('Camera', 'Keyboard') -> ('Mouse', 'Smartphone', 'Headphones', 'nan') (confidence: 0.47)
# ('Headphones', 'Smartphone') -> ('Mouse', 'Camera', 'nan', 'Keyboard') (confidence: 0.60)
# ('Headphones', 'nan') -> ('Keyboard', 'Mouse', 'Camera', 'Smartphone') (confidence: 0.60)
# ('Headphones', 'Keyboard') -> ('Mouse', 'Camera', 'nan', 'Smartphone') (confidence: 0.57)
# ('Smartphone', 'nan') -> ('Mouse', 'Camera', 'Headphones', 'Keyboard') (confidence: 0.62)
# ('Smartphone', 'Keyboard') -> ('Mouse', 'Camera', 'Headphones', 'nan') (confidence: 0.62)
# ('nan', 'Keyboard') -> ('Mouse', 'Camera', 'Headphones', 'Smartphone') (confidence: 0.62)
# ('Mouse', 'Camera', 'Headphones') -> ('Keyboard', 'Smartphone', 'nan') (confidence: 0.35)
# ('Mouse', 'Camera', 'Smartphone') -> ('Keyboard', 'Headphones', 'nan') (confidence: 0.35)
# ('Mouse', 'Camera', 'nan') -> ('Keyboard', 'Smartphone', 'Headphones') (confidence: 0.33)
# ('Mouse', 'Camera', 'Keyboard') -> ('Smartphone', 'Headphones', 'nan') (confidence: 0.40)
# ('Mouse', 'Headphones', 'Smartphone') -> ('Keyboard', 'Camera', 'nan') (confidence: 0.42)
# ('Mouse', 'Headphones', 'nan') -> ('Keyboard', 'Camera', 'Smartphone') (confidence: 0.38)
# ('Mouse', 'Headphones', 'Keyboard') -> ('Camera', 'nan', 'Smartphone') (confidence: 0.42)
# ('Mouse', 'Smartphone', 'nan') -> ('Keyboard', 'Camera', 'Headphones') (confidence: 0.38)
# ('Mouse', 'Smartphone', 'Keyboard') -> ('Camera', 'Headphones', 'nan') (confidence: 0.42)
# ('Mouse', 'nan', 'Keyboard') -> ('Camera', 'Headphones', 'Smartphone') (confidence: 0.38)
# ('Camera', 'Headphones', 'Smartphone') -> ('Mouse', 'Keyboard', 'nan') (confidence: 0.35)
# ('Camera', 'Headphones', 'nan') -> ('Mouse', 'Smartphone', 'Keyboard') (confidence: 0.30)
# ('Camera', 'Headphones', 'Keyboard') -> ('Mouse', 'Smartphone', 'nan') (confidence: 0.40)
# ('Camera', 'Smartphone', 'nan') -> ('Mouse', 'Keyboard', 'Headphones') (confidence: 0.33)
# ('Camera', 'Smartphone', 'Keyboard') -> ('Mouse', 'Headphones', 'nan') (confidence: 0.42)
# ('Camera', 'nan', 'Keyboard') -> ('Mouse', 'Smartphone', 'Headphones') (confidence: 0.38)
# ('Headphones', 'Smartphone', 'nan') -> ('Mouse', 'Camera', 'Keyboard') (confidence: 0.50)
# ('Headphones', 'Smartphone', 'Keyboard') -> ('Mouse', 'Camera', 'nan') (confidence: 0.53)
# ('Headphones', 'nan', 'Keyboard') -> ('Mouse', 'Camera', 'Smartphone') (confidence: 0.47)
# ('Smartphone', 'nan', 'Keyboard') -> ('Mouse', 'Camera', 'Headphones') (confidence: 0.53)
# ('Mouse', 'Camera', 'Headphones', 'Smartphone') -> ('Keyboard', 'nan') (confidence: 0.30)
# ('Mouse', 'Camera', 'Headphones', 'Keyboard') -> ('Smartphone', 'nan') (confidence: 0.35)
# ('Mouse', 'Camera', 'Smartphone', 'Keyboard') -> ('Headphones', 'nan') (confidence: 0.35)
# ('Mouse', 'Camera', 'nan', 'Keyboard') -> ('Smartphone', 'Headphones') (confidence: 0.30)
# ('Mouse', 'Headphones', 'Smartphone', 'nan') -> ('Keyboard', 'Camera') (confidence: 0.33)
# ('Mouse', 'Headphones', 'Smartphone', 'Keyboard') -> ('Camera', 'nan') (confidence: 0.38)
# ('Mouse', 'Headphones', 'nan', 'Keyboard') -> ('Camera', 'Smartphone') (confidence: 0.33)
# ('Mouse', 'Smartphone', 'nan', 'Keyboard') -> ('Camera', 'Headphones') (confidence: 0.33)
# ('Camera', 'Headphones', 'Smartphone', 'Keyboard') -> ('Mouse', 'nan') (confidence: 0.35)
# ('Camera', 'Headphones', 'nan', 'Keyboard') -> ('Mouse', 'Smartphone') (confidence: 0.30)
# ('Camera', 'Smartphone', 'nan', 'Keyboard') -> ('Mouse', 'Headphones') (confidence: 0.33)
# ('Headphones', 'Smartphone', 'nan', 'Keyboard') -> ('Mouse', 'Camera') (confidence: 0.42)
# ('Mouse', 'Camera', 'Headphones', 'Smartphone', 'Keyboard') -> ('nan',) (confidence: 0.30)
# ('Camera',) -> ('Monitor', 'Charger', 'nan') (confidence: 0.50)
# ('Monitor',) -> ('Camera', 'Charger', 'nan') (confidence: 0.68)
# ('nan',) -> ('Camera', 'Monitor', 'Charger') (confidence: 0.90)
# ('Charger',) -> ('Camera', 'Monitor', 'nan') (confidence: 0.55)
# ('Camera', 'Monitor') -> ('Charger', 'nan') (confidence: 0.38)
# ('Camera', 'nan') -> ('Monitor', 'Charger') (confidence: 0.40)
# ('Camera', 'Charger') -> ('Monitor', 'nan') (confidence: 0.42)
# ('Monitor', 'nan') -> ('Camera', 'Charger') (confidence: 0.57)
# ('Monitor', 'Charger') -> ('Camera', 'nan') (confidence: 0.42)
# ('nan', 'Charger') -> ('Camera', 'Monitor') (confidence: 0.45)
# ('Camera', 'Monitor', 'Charger') -> ('nan',) (confidence: 0.33)
# ('Camera', 'nan', 'Charger') -> ('Monitor',) (confidence: 0.33)
# ('Monitor', 'nan', 'Charger') -> ('Camera',) (confidence: 0.33)
# ('Laptop',) -> ('Keyboard', 'Monitor', 'nan') (confidence: 0.68)
# ('Monitor',) -> ('Keyboard', 'Laptop', 'nan') (confidence: 0.68)
# ('nan',) -> ('Keyboard', 'Monitor', 'Laptop') (confidence: 0.90)
# ('Keyboard',) -> ('Monitor', 'Laptop', 'nan') (confidence: 0.72)
# ('Laptop', 'Monitor') -> ('Keyboard', 'nan') (confidence: 0.55)
# ('Laptop', 'nan') -> ('Keyboard', 'Monitor') (confidence: 0.57)
# ('Laptop', 'Keyboard') -> ('Monitor', 'nan') (confidence: 0.57)
# ('Monitor', 'nan') -> ('Keyboard', 'Laptop') (confidence: 0.57)
# ('Monitor', 'Keyboard') -> ('Laptop', 'nan') (confidence: 0.55)
# ('nan', 'Keyboard') -> ('Monitor', 'Laptop') (confidence: 0.62)
# ('Laptop', 'Monitor', 'nan') -> ('Keyboard',) (confidence: 0.45)
# ('Laptop', 'Monitor', 'Keyboard') -> ('nan',) (confidence: 0.47)
# ('Laptop', 'nan', 'Keyboard') -> ('Monitor',) (confidence: 0.47)
# ('Monitor', 'nan', 'Keyboard') -> ('Laptop',) (confidence: 0.45)
# ('Camera',) -> ('Monitor', 'nan') (confidence: 0.50)
# ('Monitor',) -> ('Camera', 'nan') (confidence: 0.68)
# ('nan',) -> ('Camera', 'Monitor') (confidence: 0.90)
# ('Camera', 'Monitor') -> ('nan',) (confidence: 0.38)
# ('Camera', 'nan') -> ('Monitor',) (confidence: 0.40)
# ('Monitor', 'nan') -> ('Camera',) (confidence: 0.57)
# ('Laptop',) -> ('Keyboard', 'nan', 'Speaker') (confidence: 0.68)
# ('nan',) -> ('Keyboard', 'Laptop', 'Speaker') (confidence: 0.90)
# ('Speaker',) -> ('Keyboard', 'Laptop', 'nan') (confidence: 0.50)
# ('Keyboard',) -> ('Laptop', 'nan', 'Speaker') (confidence: 0.72)
# ('Laptop', 'nan') -> ('Keyboard', 'Speaker') (confidence: 0.57)
# ('Laptop', 'Speaker') -> ('Keyboard', 'nan') (confidence: 0.45)
# ('Laptop', 'Keyboard') -> ('nan', 'Speaker') (confidence: 0.57)
# ('nan', 'Speaker') -> ('Keyboard', 'Laptop') (confidence: 0.40)
# ('nan', 'Keyboard') -> ('Laptop', 'Speaker') (confidence: 0.62)
# ('Speaker', 'Keyboard') -> ('Laptop', 'nan') (confidence: 0.42)
# ('Laptop', 'nan', 'Speaker') -> ('Keyboard',) (confidence: 0.35)
# ('Laptop', 'nan', 'Keyboard') -> ('Speaker',) (confidence: 0.47)
# ('Laptop', 'Speaker', 'Keyboard') -> ('nan',) (confidence: 0.42)
# ('nan', 'Speaker', 'Keyboard') -> ('Laptop',) (confidence: 0.33)
# ('Camera',) -> ('Keyboard', 'Monitor', 'Headphones', 'nan') (confidence: 0.50)
# ('Headphones',) -> ('Camera', 'Keyboard', 'Monitor', 'nan') (confidence: 0.70)
# ('Monitor',) -> ('Keyboard', 'Camera', 'Headphones', 'nan') (confidence: 0.68)
# ('nan',) -> ('Camera', 'Keyboard', 'Monitor', 'Headphones') (confidence: 0.90)
# ('Keyboard',) -> ('Camera', 'Monitor', 'Headphones', 'nan') (confidence: 0.72)
# ('Camera', 'Headphones') -> ('Keyboard', 'Monitor', 'nan') (confidence: 0.40)
# ('Camera', 'Monitor') -> ('Keyboard', 'Headphones', 'nan') (confidence: 0.38)
# ('Camera', 'nan') -> ('Keyboard', 'Monitor', 'Headphones') (confidence: 0.40)
# ('Camera', 'Keyboard') -> ('Monitor', 'Headphones', 'nan') (confidence: 0.47)
# ('Headphones', 'Monitor') -> ('Keyboard', 'Camera', 'nan') (confidence: 0.65)
# ('Headphones', 'nan') -> ('Camera', 'Keyboard', 'Monitor') (confidence: 0.60)
# ('Headphones', 'Keyboard') -> ('Camera', 'Monitor', 'nan') (confidence: 0.57)
# ('Monitor', 'nan') -> ('Keyboard', 'Camera', 'Headphones') (confidence: 0.57)
# ('Monitor', 'Keyboard') -> ('Camera', 'Headphones', 'nan') (confidence: 0.55)
# ('nan', 'Keyboard') -> ('Camera', 'Monitor', 'Headphones') (confidence: 0.62)
# ('Camera', 'Headphones', 'Monitor') -> ('Keyboard', 'nan') (confidence: 0.35)
# ('Camera', 'Headphones', 'nan') -> ('Keyboard', 'Monitor') (confidence: 0.30)
# ('Camera', 'Headphones', 'Keyboard') -> ('Monitor', 'nan') (confidence: 0.40)
# ('Camera', 'Monitor', 'Keyboard') -> ('Headphones', 'nan') (confidence: 0.38)
# ('Camera', 'nan', 'Keyboard') -> ('Monitor', 'Headphones') (confidence: 0.38)
# ('Headphones', 'Monitor', 'nan') -> ('Keyboard', 'Camera') (confidence: 0.55)
# ('Headphones', 'Monitor', 'Keyboard') -> ('Camera', 'nan') (confidence: 0.53)
# ('Headphones', 'nan', 'Keyboard') -> ('Camera', 'Monitor') (confidence: 0.47)
# ('Monitor', 'nan', 'Keyboard') -> ('Camera', 'Headphones') (confidence: 0.45)
# ('Camera', 'Headphones', 'Monitor', 'Keyboard') -> ('nan',) (confidence: 0.35)
# ('Camera', 'Headphones', 'nan', 'Keyboard') -> ('Monitor',) (confidence: 0.30)
# ('Headphones', 'Monitor', 'nan', 'Keyboard') -> ('Camera',) (confidence: 0.42)
# ('Laptop',) -> ('Keyboard', 'Monitor') (confidence: 0.68)
# ('Monitor',) -> ('Keyboard', 'Laptop') (confidence: 0.68)
# ('Keyboard',) -> ('Monitor', 'Laptop') (confidence: 0.72)
# ('Laptop', 'Monitor') -> ('Keyboard',) (confidence: 0.55)
# ('Laptop', 'Keyboard') -> ('Monitor',) (confidence: 0.57)
# ('Monitor', 'Keyboard') -> ('Laptop',) (confidence: 0.55)
